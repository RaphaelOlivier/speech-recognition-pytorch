# %%
import numpy as np

# %%
data=np.load("../data/dev_transcripts.npy")

# %%
heldout = data[-20:]

# %%
for s in heldout:
    print(s)
# Out:
# DOCTOR PIERCE SAID READERS OF PHILIP MORRIS'S MAGAZINE PROBABLY ARE BETTER EDUCATED THAN THE TYPICAL SMOKER PERIOD
# MOREOVER COMMA PHILIP MORRIS SAID THAT TWENTY FIVE PERCENT OF THE SURVEY RESPONDENTS WERE NON HYPHEN SMOKERS PERIOD
# A SPOKESMAN FOR PEPSICO INCORPORATED SAID COLON DOUBLE-QUOTE WE HAVE NO IMMEDIATE PLANS TO GO TO SUCROSE PERIOD
# HOWEVER COMMA PEPSI IS ALWAYS EXPLORING DIFFERENT COMMA MORE ECONOMIC WAYS TO SWEETEN OUR DRINKS PERIOD
# IF THE PRICE OF SUCROSE BECOMES COMPETITIVE WITH HIGH FRUCTOSE CORN SYRUP COMMA WE'D CONSIDER OUR OPTIONS PERIOD DOUBLE-QUOTE
# SUCROSE IS A SUGAR EXTRACTED FROM SUGAR CANE OR SUGAR BEETS PERIOD
# RECALLING THE LONG SOVIET SILENCE AFTER CHERNOBYL COMMA WESTERN DIPLOMATS WELCOME THIS GREENING OF MOSCOW OFFICIALDOM PERIOD
# BUT SOME SUSPECT THE DECLARATIONS ABOUT COOPERATION ARE AIMED AT WEST GERMANY COMMA WHERE PUBLIC ALARM ABOUT THE ENVIRONMENT RUNS HIGH PERIOD
# MUCH OF THE POLLUTION KILLING GERMAN FORESTS IS BLOWN FROM THE EAST PERIOD
# ...
